# %%
import pandas as pd
import numpy as np

path = "/Users/torreshong/Documents/GitHub/DS105_Project/6622_jobs.xls"

df_import = pd.read_excel(path)
df_import.shape
df_import
# Out:
# (6623, 11)

# %%
df_import
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Rothschild & Co - Private Equity Long-Term Int...
# 1              1  2023 HSBC Global Graduate Programme (Hong Kong...
# 2              2  2023 HSBC Global Internship Programme (Hong Ko...
# 3              3         Graduate Training Scheme, Capital Markets
# 4              4           6-Months Internship – Sell-side Tech M&A
# ...          ...                                                ...
# 6618        6618  2012 Summer Internship - Financial Software De...
# 6619        6619     Technical Consultant - Graduate Programme 2012
# 6620        6620  Risk Implementation Consultant - Graduate Prog...
# 6621        6621       Project Consultant - Graduate Programme 2012
# 6622        6622                       Analyst - Investment Banking
#
#                                                 details   deadline  \
# 0     This London-based 6-month internship is an exc... 2023-04-30
# 1     You’re excited about starting your career and ... 2023-01-06
# 2     You’re excited about starting your career and ... 2023-01-06
# 3     Graduate Training Scheme – LondonGreySpark Par... 2022-12-17
# 4     At IPTP, we understand software from decades o... 2022-12-31
# ...                                                 ...        ...
# 6618  Business: Financial Systems Area: Capital Mark... 2012-05-31
# 6619  TECHNICAL CONSULTANTBusiness: Financial System... 2012-05-31
# 6620  RISK IMPLEMENTATION CONSULTANTBusiness: Financ... 2012-05-31
# 6621  PROJECT CONSULTANTBusiness: Financial Systems ... 2012-05-31
# 6622  Description:UBS is one of the world's leading ... 2012-06-01
#
#               opport_type                                   commence_date  \
# 0              Internship                             2023-07-01 00:00:00
# 1     Graduate employment                             2023-07-03 00:00:00
# 2              Internship                             2023-06-05 00:00:00
# 3     Graduate employment                                    9th Jan 2023
# 4              Internship                                      01/01/2023
# ...                   ...                                             ...
# 6618    All types of work                                             NaN
# 6619    All types of work  Graduate Induction Week: 3rd of September 2012
# 6620    All types of work  Graduate Induction Week: 3rd of September 2012
# 6621    All types of work   Graduate Induction Week:3rd of September 2012
# 6622    All types of work                             2012-07-01 00:00:00
#
#      contract_type            location        Renumeration  \
# 0        Temporary              London                 NaN
# 1        Temporary  Hong KongSingapore                 NaN
# 2        Temporary  Hong KongSingapore                 NaN
# 3        Permanent              London                 NaN
# 4        Temporary              France                 NaN
# ...            ...                 ...                 ...
# 6618           NaN                      Salary competitive
# 6619           NaN                      Salary competitive
# 6620           NaN                      Salary competitive
# 6621           NaN                      Salary competitive
# 6622           NaN              London  Salary competitive
#
#                                           company  \
# 0                                 Rothschild & Co
# 1                         HSBC (HSBC) - Hong Kong
# 2                         HSBC (HSBC) - Hong Kong
# 3                          GreySpark Partners Ltd
# 4     Inflexion Points Technology Partners (IPTP)
# ...                                           ...
# 6618                             FIS Global (FIS)
# 6619                             FIS Global (FIS)
# 6620                             FIS Global (FIS)
# 6621                             FIS Global (FIS)
# 6622                                          UBS
#
#                                                   links
# 0     https://careers.lse.ac.uk//students/jobs/detai...
# 1     https://careers.lse.ac.uk//students/jobs/detai...
# 2     https://careers.lse.ac.uk//students/jobs/detai...
# 3     https://careers.lse.ac.uk//students/jobs/detai...
# 4     https://careers.lse.ac.uk//students/jobs/detai...
# ...                                                 ...
# 6618  https://careers.lse.ac.uk//students/jobs/detai...
# 6619  https://careers.lse.ac.uk//students/jobs/detai...
# 6620  https://careers.lse.ac.uk//students/jobs/detai...
# 6621  https://careers.lse.ac.uk//students/jobs/detai...
# 6622  https://careers.lse.ac.uk//students/jobs/detai...
#
# [6623 rows x 11 columns]

# %%
df_company_names = df_import.iloc[:, 9]
df_company_names.shape
# Out:
# (6623,)

# %%
df_company_names.iloc[1]
# Out:
# 'HSBC (HSBC) - Hong Kong'

# %%
name_counts = df_company_names.value_counts()

import matplotlib.pyplot as plt

top_10 = name_counts.nlargest(10)

top_10.plot(kind='bar')
plt.title("Top 10 Companies with the most Job Postings")
plt.xlabel("Company Name")
plt.ylabel("Number of Job Postings")

plt.show()
